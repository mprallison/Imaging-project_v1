# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import cv2 
import skimage
import scipy
from skimage import io
from skimage import external
from simple_functions import floorValues

# %%
with skimage.external.tifffile.TiffFile('test.tif') as tif:
    data = tif.asarray()
tif.close()

# %%
im = data[0]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage import feature

# Compute the Canny filter for two values of sigma
edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=0.001)

# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
edges2
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True,  True, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False,  True,  True, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
x = feature.canny(data[0])

# %%
y = feature.canny(x)

plt.figure(figsize=(10,10))
ax = plt.subplot()
ax.imshow(y)
plt.show()

# %%
ax = plt.subplot()
x = data[0]
ax.imshow(x)
plt.show()

# %%
from scipy import ndimage as ndi

# %%
z = ndi.binary_fill_holes(y)

fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(z, cmap=plt.cm.gray, interpolation='nearest')
ax.axis('off')
ax.set_title('Filling the holes')
# Out:
# Text(0.5, 1.0, 'Filling the holes')
